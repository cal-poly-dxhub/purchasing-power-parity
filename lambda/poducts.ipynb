# %%
import pandas as pd
import numpy as np

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

pd.read_csv('products.csv')
# Out:
#                                            description               brand
# 0    All Natural* 93% Lean/7% Fat Lean Ground Beef ...                 NaN
# 1       All Natural* 73% Lean/27% Fat Lean Ground Beef                 NaN
# 2          Beef Bottom Round Steak Thin, 0.34 - 2.0 lb                 NaN
# 3    All Natural* 80% Lean/20% Fat Ground Beef Chuc...                 NaN
# 4    All Natural* 80% Lean/20% Fat Ground Beef Chuc...                 NaN
# 5            Beef Stew Meat Family Pack, 2.15 - 3.0 lb                 NaN
# 6                       Beef Stew Meat, 0.68 - 1.31 lb                 NaN
# 7    All Natural* 80% Lean/20% Fat Ground Beef Chuc...                 NaN
# 8    All Natural* 73% Lean/27% Fat Ground Beef Roll...                 NaN
# 9    All Natural* 93% Lean/7% Fat Lean Ground Beef ...                 NaN
# 10           Beef Carne Para Deshebrar, 1.22 - 2.22 lb                 NaN
# ...
